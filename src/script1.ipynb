# %% [markdown]
# <h1>Get conserved clusters intra species<h1/>

# %% [markdown]
# <h2>Import librairies

# %%
import pymongo
from pymongo import mongo_client
import pandas as pd

# %% [markdown]
# <h2>Connect to MongoDB

# %%
from pymongo import mongo_client


MongoClient = pymongo.MongoClient("localhost", 27017)


clusters_db = "LPM_w15_ncc"   #nuclear proteome


familly = clusters_db

conserved_cluster_intra = "Conserved_cluster_intra"

ConcervedINTRA = MongoClient[conserved_cluster_intra]
clusterDB = MongoClient[clusters_db]
#clusterMDB = MongoClient[clusters_m_db]

# %%
species = clusterDB.list_collection_names()  # activate when screening among NM


for specie in species:
    print(specie)
    collections = clusterDB.get_collection(specie)
    documents = collections.find()
    for item in documents:
        #print(item)
        cluster = item["cluster"]

        cnt = collections.count_documents(
            {"cluster": cluster, "id": {"$ne": item["id"]}}
        )

        if cnt > 0:
            print(cnt)
            collec = ConcervedINTRA.get_collection(familly)
            if collec.find_one({"specie": specie}):
                if collec.find_one({"$and": [
                    {"specie": specie},
                    {f"clusters.{cluster}": {"$exists": True}}]}):
                    print("cluster exist")
                    collec.update_one({"$and": [
                    {"specie": specie},
                    {f"clusters.{cluster}": {"$exists": True}}]},
                        {"$push": {f"clusters.{cluster}.ids": item["id"]}},
                    )
                else:
                    print("insert new cluster")
                    collec.update_one(
                        {"specie": specie},
                        {"$set": {f"clusters.{cluster}": {"ids": [item["id"]]}}},
                    )
            else:
                print("new doc")
                entry = {"specie": specie, "clusters": {cluster: {"ids": [item["id"]]}}}
                collec.insert_one(entry)

# %% [markdown]
# # Get CC within same species across different nuclear/mitochondrial proteomes

# %%
from pymongo import mongo_client


MongoClient = pymongo.MongoClient("localhost", 27017)


clusters_nm_db = "GANM_w15_pcc"   #nuclear proteome
clusters_m_db = "GAM_w15_pcc"     #mitochondrial protteome

familly = 'conserved_N/M_pcc_GA'

conserved_cluster_intra = "Conserved_cluster_intra"

ConcervedINTRA = MongoClient[conserved_cluster_intra]
clusterDB = MongoClient[clusters_nm_db]
clusterMDB = MongoClient[clusters_m_db]

# %%
species = clusterDB.list_collection_names()  # activate when screening among NM
speciesM = clusterMDB.list_collection_names() #activate when screening among M
#print(speciesM)
for specie in species:
    for speciem in speciesM:
        if speciem ==specie.lower() :
            #print(speciem)
            collections = clusterDB.get_collection(specie)
            collectionsM= clusterMDB.get_collection(specie.lower())
            documents = collections.find()
            documentsM=collectionsM.find()
            for item in documents:
                #print(item)
                cluster = item["cluster"]

                cnt = collectionsM.count_documents(
                    {"cluster": cluster, "id": {"$ne": item["id"]}}
                )

                if cnt > 0:
                    print(cnt,speciem,cluster)
                    documentsM=collectionsM.find_one({"cluster": cluster})
                    collec = ConcervedINTRA.get_collection(familly)
                    entry = {"specie": specie, "clusters": {cluster: {"ids": [item["id"]], "idsM": [documentsM["id"]] }}}
                    collec.insert_one(entry)
